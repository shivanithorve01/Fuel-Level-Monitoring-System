# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model, metrics

# %%
df = pd.read_csv('/content/drive/MyDrive/AP Lab/AP OEA/DistVSLitre.csv', )
df.head()
# Out:
#      ml   cm
# 0   300  1.6
# 1   400  1.8
# 2   500  2.0
# 3   600  2.2
# 4  1000  3.0

# %%
df.describe()
# Out:
#                 ml         cm
# count    27.000000  27.000000
# mean   2700.000000   7.059259
# std    1525.173382   3.533712
# min     300.000000   1.600000
# 25%    1550.000000   4.300000
# 50%    2600.000000   7.000000
# 75%    3950.000000  10.050000
# max    5300.000000  13.100000

# %%
y = df.loc[:,'ml']
x = df.loc[:,'cm']
#print(x)

# %%
#print(y)

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.30 ,random_state= 42)

# %%
#print(x_train)

# %%
#print(y_train)

# %%
#print(x_test)

# %%
#print(y_test)

# %%
plt.plot(x, y, '-ok');

# %%
import statsmodels.api as sm

# %%
#Change x_train data to constant 1
x_train_new = sm.add_constant(x_train)
print(x_train_new)

# %%
y_train_pred = sm.OLS(y_train,x_train_new).fit()

print(y_train_pred.params)

# %%
x_test_new = sm.add_constant(x_test)
print(x_test_new)

# %%
pred_y = y_train_pred.predict(x_test_new)
print(pred_y)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,pred_y,'r')

#To add title to graph
plt.title(" Graph of model performance ")

#To add labels to X and Y axes
plt.xlabel('ml')
plt.ylabel('cm')

plt.show()

# %%
from sklearn.metrics import r2_score , mean_squared_error

# %%
import numpy as np

# %%
R2 = np.abs(r2_score(y_test , pred_y))
print("R2 = ",R2)
RMSE = np.sqrt(mean_squared_error(y_test,pred_y))
print("RMSE = ",RMSE)
# Out:
# R2 =  0.9968698297291126
# RMSE =  59.353130477321024

# %%
#slope & Intercept of the line
slope_Intercept = np.polyfit(x,y,1)
print(slope_Intercept)
# slope = 431.36747145
# intercept = -345.13481695
# Out:
# [ 431.36747145 -345.13481695]
